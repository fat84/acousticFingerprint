# %% [markdown]
# #### Create Fourier transforms on different types of series
#
# Ideas and some source code is from: https://drive.google.com/open?id=1AH6C4mHoORVgCusW78J2_brGR5JIhNxd

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Set parameters for this instance of Jupyter Notebook
# %matplotlib inline
# %precision 4

file_location = "C:/Users/bre49823/Google Drive/AudioFiles/"

# %%
# Fourier transform of a sine wave
sampling_rate = 150
time = np.arange(0, 1, 1/sampling_rate)              # The step is 1/150

frequency = 5                                       # Frequency in Hz
signal = np.square(2 * np.pi * time * frequency)   # Create a sin wave with a period of "frequency"
nfft = 1024                                         # Length of FFT

# Plot raw data
plt.figure(figsize = (15, 5))
plt.plot(time, signal)
plt.title("Raw Signal Data")
plt.xlabel("Time")
plt.ylabel("Amplitude")

# Write the audio file to hear what it sounds like. Change the parameters and note how the sound changes
#wavfile.write(data = sin_wave, filename = file_location + "test.wav", rate = sampling_rate)

# Define a Hanning window


# Create Fourier transform
nfft = 1024
signal_fft = np.fft.rfft(signal, n = nfft)

plt.figure(figsize = (15, 5))
plt.plot(signal_fft)
plt.title("FFT Results")
plt.ylabel("Power")

# Calculate the magnitude of FFT
signal_fft_abs = np.abs(signal_fft)

plt.figure(figsize = (15, 5))
plt.plot(signal_fft_abs)
plt.title("Absolute Values of FFT")
plt.ylabel("Power")

# Frequency vector
freq_vector = np.arange(0, nfft/2 + 1) * (sampling_rate / nfft)
freq_vector.shape

plt.figure(figsize = (15, 5))
plt.plot(freq_vector, signal_fft_abs)
plt.title('Power Spectrum of a Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power')
# Out:
# C:\Users\bre49823\AppData\Local\Continuum\Anaconda2\envs\py36\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
time
# Out:
# array([ 0.    ,  0.0067,  0.0133,  0.02  ,  0.0267,  0.0333,  0.04  ,
#         0.0467,  0.0533,  0.06  ,  0.0667,  0.0733,  0.08  ,  0.0867,
#         0.0933,  0.1   ,  0.1067,  0.1133,  0.12  ,  0.1267,  0.1333,
#         0.14  ,  0.1467,  0.1533,  0.16  ,  0.1667,  0.1733,  0.18  ,
#         0.1867,  0.1933,  0.2   ,  0.2067,  0.2133,  0.22  ,  0.2267,
#         0.2333,  0.24  ,  0.2467,  0.2533,  0.26  ,  0.2667,  0.2733,
#         0.28  ,  0.2867,  0.2933,  0.3   ,  0.3067,  0.3133,  0.32  ,
#         0.3267,  0.3333,  0.34  ,  0.3467,  0.3533,  0.36  ,  0.3667,
#         0.3733,  0.38  ,  0.3867,  0.3933,  0.4   ,  0.4067,  0.4133,
#         0.42  ,  0.4267,  0.4333,  0.44  ,  0.4467,  0.4533,  0.46  ,
#         0.4667,  0.4733,  0.48  ,  0.4867,  0.4933,  0.5   ,  0.5067,
#         0.5133,  0.52  ,  0.5267,  0.5333,  0.54  ,  0.5467,  0.5533,
#         0.56  ,  0.5667,  0.5733,  0.58  ,  0.5867,  0.5933,  0.6   ,
#         0.6067,  0.6133,  0.62  ,  0.6267,  0.6333,  0.64  ,  0.6467,
#         0.6533,  0.66  ,  0.6667,  0.6733,  0.68  ,  0.6867,  0.6933,
#         0.7   ,  0.7067,  0.7133,  0.72  ,  0.7267,  0.7333,  0.74  ,
#         0.7467,  0.7533,  0.76  ,  0.7667,  0.7733,  0.78  ,  0.7867,
